# %% [markdown]
# # Mage AI - Notebook del alumno
#
# ## Objetivo
# Construir y entender un pipeline sencillo con este flujo:
#
# **CSV → transformación → resumen → exportación**
#
# Completa las celdas marcadas con `TODO`.

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path('../data/supermarket_sales_small.csv')

# %% [markdown]
# ## 1. Carga del dataset
#
# Lee el fichero CSV en un DataFrame llamado `df`.

# %%
# TODO
df = None
df.head()

# %% [markdown]
# ## 2. Explora la estructura
#
# Muestra la información general del DataFrame.

# %%
# TODO

# %% [markdown]
# ## 3. Crea una copia de trabajo
#
# Guárdala en una variable llamada `work`.

# %%
# TODO
work = None

# %% [markdown]
# ## 4. Conversión de fechas
#
# Convierte la columna `Date` a tipo fecha.

# %%
# TODO

# %% [markdown]
# ## 5. Nueva columna derivada
#
# Crea una columna llamada `ingreso_neto_estimado` con esta fórmula:
#
# `Total - Tax 5%`

# %%
# TODO

# %% [markdown]
# ## 6. Agrupación
#
# Agrupa por `Product line` y calcula:
# - `ventas_totales`: suma de `Total`
# - `media_rating`: media de `Rating`
# - `tickets`: recuento de `Invoice ID`
#
# Ordena el resultado por `ventas_totales` de mayor a menor.

# %%
# TODO
resumen = None
resumen

# %% [markdown]
# ## 7. Exportación
#
# Guarda el resumen en `../data/resumen_product_line_alumno.csv`

# %%
# TODO

# %% [markdown]
# ## 8. Traducción a Mage AI
#
# Rellena el código de estos tres bloques.
#
# ### Data Loader

# %%
import pandas as pd

def load_data(*args, **kwargs):
    # TODO
    pass

# %% [markdown]
# ### Transformer

# %%
def transform(df, *args, **kwargs):
    # TODO
    return df

# %% [markdown]
# ### Data Exporter

# %%
def export_data(df, *args, **kwargs):
    # TODO
    pass

# %% [markdown]
# ## 9. Reflexión final
#
# Responde brevemente:
# 1. ¿Qué hace Mage AI que no haga directamente `pandas`?
# 2. ¿Qué parte del trabajo sigue siendo puramente Python?
# 3. ¿Qué ventajas tiene una interfaz visual para depurar pipelines?
